# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Funciones y algebra básica

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Funciones lineales

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Ejemplos: funciones lineales

# %% [markdown]
# Costos de transporte de camiones
#
# Costo = f(distancia) = $ 200 + 1.35 $ / km * distancia
#
#
# Costos de almacenamiento
#
# Costo = f (# cajas) = € 2,500 + 2.5 € / caja * (#cajas)

# %%
km = int(input("¿Cuántos km? "))
costefijo1 = int(input("Coste fijo "))
costeporkm = float(input("Coste por km "))
costo = costefijo1+(costeporkm*km)
print(costo)

# %% [markdown]
# ##### Ejemplo: impacto del peso del transporte de paquetes
# Los transportistas de paquetes combinan muchos pedidos en un solo envío.
# El costo de un pedido individual es una función de su peso, w.
# Sin embargo, no es lineal, se está abaratando:

# %%
## costo = f (peso) = 33 + 0.067 w - 0.00005, distancia elevado a 2
w = int(input("¿Cuántos km? "))
fijo3 = int(input("¿Coste fijo? "))
costevariable = float(input("Coste variable por km menor que 1"))
costevariablemas = float(input("Coste variable por más distancia menor que 0.0001 "))
costo2 = (fijo3+(costevariable*w))-(costevariablemas*(w**2))
costo2
